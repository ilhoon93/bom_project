# %%
import sys
import pandas as pd
from pandas import Series, DataFrame
import re
import numpy as np
from requests import get
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from datetime import date,timedelta,datetime
import time
import json
import calendar
import math
from konlpy.tag import Twitter as original_Twitter
from ckonlpy.tag import Twitter
from bom_text_preprocessor import BOM_EMOJI
from bom_text_preprocessor import emoji2text
from bom_text_preprocessor import dataframe2json
from bom_text_preprocessor import pnormalizer # 'gl','powder','meme'
from pymongo import MongoClient

# %%
client=MongoClient("mongodb://pungdeong:pungdeong@13.125.143.101/pungdeongBOM")
db = client.pungdeongBOM
raw_product_DB=db.product_DB
raw_normalizer=db.normalizer
ex_product_DB = pd.Series([doc for doc in raw_product_DB.find()])
ex_normalizer = pd.Series([doc for doc in raw_normalizer.find()])

# %%
# 데이터 프레임화
# normalizer
nor_brandname=[ex_normalizer[i]['brandname'] for i in range(len(ex_normalizer))]
nor_origin=[ex_normalizer[i]['origin'] for i in range(len(ex_normalizer))]
nor_pname=[ex_normalizer[i]['pname'] for i in range(len(ex_normalizer))]
nor_site=[ex_normalizer[i]['site'] for i in range(len(ex_normalizer))]
# product_DB
pdb_brandname=[ex_product_DB[i]['product']['brandname'] for i in range(len(ex_product_DB))]
pdb_category=[ex_product_DB[i]['product']['category'] for i in range(len(ex_product_DB))]
pdb_gl_num_rev=[ex_product_DB[i]['product']['gl_num_rev'] for i in range(len(ex_product_DB))]
pdb_origin_id=[ex_product_DB[i]['product']['origin_id'] for i in range(len(ex_product_DB))]
pdb_pid=[ex_product_DB[i]['product']['pid'] for i in range(len(ex_product_DB))]
pdb_pname=[ex_product_DB[i]['product']['pname'] for i in range(len(ex_product_DB))]
pdb_product_attribute=[ex_product_DB[i]['product']['product_attribute'] for i in range(len(ex_product_DB))]
pdb_product_desc=[ex_product_DB[i]['product']['product_desc'] for i in range(len(ex_product_DB))]
pdb_product_price=[ex_product_DB[i]['product']['product_price'] for i in range(len(ex_product_DB))]
pdb_product_volume=[ex_product_DB[i]['product']['product_volume'] for i in range(len(ex_product_DB))]
pdb_sales=[ex_product_DB[i]['product']['sales'] for i in range(len(ex_product_DB))]
pdb_review=[ex_product_DB[i]['review'] for i in range(len(ex_product_DB))]
pdb_user=[ex_product_DB[i]['user'] for i in range(len(ex_product_DB))]

# %%
data=pd.DataFrame(
    {'brandname':nor_brandname,
    'origin':nor_origin,
    'pname':nor_pname,
    'site':nor_site})
normalizer_df=DataFrame(data)
normalizer_df=DataFrame(data, columns=['brandname',"origin",'pname','site'])

data = pd.DataFrame(
            {'brandname': pdb_brandname,
            'category': pdb_category,
             'gl_num_rev' : pdb_gl_num_rev,
             'origin_id':pdb_origin_id,
             'pid':pdb_pid,
             'pname':pdb_pname,
             'product_attribute':pdb_product_attribute,
             'product_desc':pdb_product_desc,
             'product_price':pdb_product_price,
             'product_volume':pdb_product_volume,
             'sales':pdb_sales,
             'review':pdb_review,
             'user':pdb_user
            })
product_df=DataFrame(data)
product_df=DataFrame(data, columns=['brandname',"category",'gl_num_rev','origin_id','pid','pname','product_attribute','product_desc','product_price','product_volume','sales','review','user'])

# %%
# load essential data
# 데이터프레임형태
product_DB = product_df
normalizer = normalizer_df

# %%
########################################## 크롤링 코드 ###############################

# %%
score_dict = {'worst': 1, 'bad': 2, 'soso': 3, 'good': 4, 'best':5}
pd_c_list={100:"모공",200:"각질",300:"주름",400:"잡티",500:"건조함",600:"피부톤",700:"민감성",800:"트러블",900:"아토피",1000:"피지과다"}
pd_s_type={100:"건성",200:"중성",300:"지성",400:"복합성"}
mm_score_dic ={"":0,"half":0.5,"one":1,"oneHalf":1.5,"two":2,"twoHalf":2.5,"three":3,"threeHalf":3.5,"four":4,"fourHalf":4.5,"five":5} 
    # 별점이 숫자가 아닌 텍스트로 되어있음. 텍스트에 대응되는 별점 딕셔너리

# %%
# 별의 텍스트를 뽑아내는 함수  
def mm_starnum(star):
    first=0
    second=0
    for i in range(len(star)):
        if star[i]=="\"":
            if first==0:
                first=i
            else: 
                second=i
    return star[first+1:second]
# 날짜 텍스트를 변환해주는 함수
def date_transfer(date_info):
    
    year=int(str(datetime.today())[:4]) # 오늘 년
    month=int(str(datetime.today())[5:7]) # 오늘 월
    day=int(str(datetime.today())[8:10]) # 오늘 일 
    
    if "초 전" in date_info or "초전" in date_info:
        n_date=date(year,month,day)
        n_date='{:%Y-%m-%d}'.format(n_date)
    
    elif "분 전" in date_info or "분전" in date_info:
        n_date=date(year,month,day)
        n_date='{:%Y-%m-%d}'.format(n_date)
        
    elif "시간 전" in date_info or "시간전" in date_info:
        n_date=date(year,month,day)
        n_date='{:%Y-%m-%d}'.format(n_date)

    
    elif "일 전" in date_info or "일전" in date_info:
        d_day=int(re.sub("[^0-9]","",date_info))
        if (day-d_day)>=1:
            n_date=date(year,month,(day-d_day))
            n_date='{:%Y-%m-%d}'.format(n_date)

        else:
            lastday=calendar.monthrange(year,month-1)[1]
            temp=lastday-d_day
            n_date=date(year,(month-1),(temp+day))
            n_date='{:%Y-%m-%d}'.format(n_date)
      

    elif "개월 전" in date_info or "개월전" in date_info:
        n_month=int(re.sub("[^0-9]","",date_info)) # 몇 달전 인지
        
        if (month-n_month)>=1:
            n_date=date(year,(month-n_month),day)
            n_date='{:%Y-%m-%d}'.format(n_date)

        else:
            temp=12-n_month
            n_date=date(year,(temp+month),day)
            n_date='{:%Y-%m-%d}'.format(n_date)

    else:
        n_date=date_info
        
    return n_date

# %%
meme_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/memebox/meme_id.csv')
gl_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/glowpick/gl_id.csv')
pod_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/powderroom/pod_id.csv')

# %%
# 뷰티 리뷰 사이트에 원하는 제품을 입력하면 리뷰를 주기적으로 가져오는 크롤러
# 미미박스, 글로우픽, 파우더룸
# 모든 제품 리뷰를 실시간으로 가져옴 

class bom_crawler():
    import sys
    import pandas as pd
    from pandas import Series, DataFrame
    import re
    import numpy as np
    from requests import get
    from bs4 import BeautifulSoup as bs
    from selenium import webdriver
    from datetime import date,timedelta,datetime
    import time
    import json
    import calendar
    import math

    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
    t_date=datetime.today().strftime('%Y-%m-%d') # 오늘 
    yesterday = date.today() - timedelta(1)
    y_date=yesterday.strftime('%Y-%m-%d') # 어제

    def __init__(self): # 인스턴스 속성- 변수에 들어가있는 값이 클래스 별로 다르다.
        #product
        self.pid=[] # 제품 id - int 
        self.pname=[] # 제품 이름 - string
        self.brandname=[] # 브랜드이름 - string
        self.category=[] # 제품 카테고리 - string
     
        # user
        self.age=[] # 나이 - int
        self.concern_list=[] # 피부고민 - list[string]
        self.skin_type=[] # 피부타입 - string
        self.repurchased=[] # 재구매여부 - boolean

        # review
        self.d_date=[] # 리뷰 생성날짜 - datetime
        self.score=[] # 리뷰 평점 - float
        self.like_c=[] # 좋아요개수 - int
        self.tags=[] # 제품태그 - list[string]
        self.text=[] # 리뷰 - string

    ## 클래스 메소드
    # @classmethod 

    ### 인스턴스 메소드 

    # 미미박스 크롤링함수
    def meme_review_crawl(self):
        for p_id in meme_id['pid']:
            url = 'https://www.memebox.com/ajax/reviews?productId='+str(p_id)+'&orderType=createdatDESC&page=1&contentViewPickOption=all'
            html = get(url,headers=self.headers).text
            soup = bs(html,'lxml')
            print(url)
            print("****************************************************")
            for k in range(len(soup.select('body > form > div.view'))):
                r_date=date_transfer(soup.select('div.info')[k].select('span.date')[0].text)
                if r_date==self.t_date or r_date==self.y_date: # 리뷰 날짜가 오늘이나 어제와 같다면
                    
                    ### product
                    self.pid.append(meme_id.loc[meme_id.pid==p_id,'pid'].values[0]) # item_id
                    self.pname.append(meme_id.loc[meme_id.pid==p_id,'pname'].values[0])# item_name
                    self.brandname.append(meme_id.loc[meme_id.pid==p_id,'brandname'].values[0])# brand_name
                    self.category.append(meme_id.loc[meme_id.pid==p_id,'category'].values[0])# category
                     
                    #review
                    # date 아래에 
                    self.score.append(mm_score_dic[mm_starnum(str(soup.select('span.star > em')[k]))]) # 리뷰 평점
                    self.like_c.append(re.sub("\n| ","",soup.select('span.like-thumb-text')[k].text))  # 리뷰 좋아요 개수
                    self.tags.append(" ") # 태그
                    self.text.append(re.sub('\t','',soup.select('div > p.reviews-written-text-deal-detail')[k].text).strip()) # 리뷰 텍스트

                    
                    ### user
                    self.age.append(" ")# 나이 
                    if len(soup.select('div.info')[k].select('span'))==2: #  피부타입 & 리뷰 작성일
                        self.skin_type.append(re.sub("/","",soup.select('div.info')[k].select('span')[0].text).strip())  
                        self.d_date.append(r_date)
                    else:
                        self.skin_type.append(" ") 
                        self.d_date.append(r_date)
                    self.concern_list.append(" ")# 피부고민    
                    if soup.select('div.review-selected-option')[k].select('span'): # 재구매 여부
                        self.repurchased.append(soup.select('div.review-selected-option')[k].select('span')[0].text)
                    else:
                        self.repurchased.append(" ")

    
    # 파우더룸 크롤링함수
    def powder_review_crawl(self):
        for p_id in pod_id['pid']:
            url='https://www.powderroom.co.kr/api/products/'+str(p_id)+'/reviews?order=new'
            html=get(url,headers=self.headers).text
            reviews=json.loads(html)
            print(url)
            print("****************************************************")
            for i in range(len(reviews)):
                date_result=pd.to_datetime(str(reviews[i]['$created'])[:-3],unit='s')
                r_date=date_result.strftime('%Y-%m-%d')      
                if r_date==self.t_date or r_date==self.y_date: # 리뷰 날짜가 오늘이나 어제와 같다면

                    ### product
                    self.pid.append(p_id) # 제품 id
                    self.pname.append(str(pod_id.loc[pod_id.pid==int(p_id),'pname'].values)[2:-2]) # 제품 이름
                    self.brandname.append(str(pod_id.loc[pod_id.pid==int(p_id),'brandname'].values)[2:-2]) #브랜드 이름
                    self.category.append(str(pod_id.loc[pod_id.pid==int(p_id),'category'].values)[2:-2]) #카테고리

                    ### review 

                    self.d_date.append(r_date) # date
                    self.score.append(reviews[i]['rate'])# score 
                    self.like_c.append(reviews[i]['count']['like'])# like_c
                    self.tags.append(reviews[i]['tags'])# tags 
                    self.text.append(reviews[i]['text']) # 텍스트 
                   
                    
                    ### user        
                    try: # json에 age 키 값이 없는 경우가 있다. (사이트에는 있음)
                        self.age.append(reviews[i]['user']['age']) # 나이 
                    except:
                        self.age.append(" ")
                    try: # 피부 타입
                        self.skin_type.append(pd_s_type[reviews[i]['user']['skin']['type']])# skin_type
                    except:
                        self.skin_type.append(" ") 

                    tmp_c_list=[]
                    try: # 피부고민, 
                        for a in reviews[i]['user']['skin']['concerns']:
                            tmp_c_list.append(pd_c_list[a])
                        self.concern_list.append(",".join(tmp_c_list))
                    except:
                        self.concern_list.append(" ") 

                    self.repurchased.append(reviews[i]['repurchased'])# repurchase
    # 글로우픽 크롤링 함수            
    def glowpick_review_crawl(self):
        chrome_path = 'C:/Users/Ilhoon/Desktop/dev_util/chromedriver_win32/chromedriver'
        options=webdriver.ChromeOptions()
        options.add_argument('headless')
        options.add_argument('window-size=1920x1080')
        options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')
        options.add_argument("disable-gpu")
        driver = webdriver.Chrome(chrome_path, chrome_options=options)

        for p_id in gl_id["pid"]:
            time.sleep(1)
            driver.get('http://glowpick.com/product/'+str(p_id)+'')
            html = driver.page_source
            soup = bs(html, 'lxml')
            print('http://glowpick.com/product/'+str(p_id)+'')
            print("****************************************************")

            for k in range(len(soup.select('section.section-list-item > ul.review-list-wrap > li'))):
                r_date=re.sub("[^0-9]","-",date_transfer(soup.select('section.section-list-item > ul.review-list-wrap > li > span.date')[k].text))   
                if r_date==self.t_date or r_date==self.y_date: # 리뷰 날짜가 오늘이나 어제와 같다면
                        
                    ### product 
                    self.pid.append(p_id) # 제품 id 
                    self.pname.append(gl_id.loc[gl_id.pid==p_id,'pname'].values[0]) # 제품 이름
                    self.brandname.append(gl_id.loc[gl_id.pid==p_id,'brandname'].values[0]) # 브랜드 이름
                    self.category.append(gl_id.loc[gl_id.pid==p_id,'category'].values[0]) # 카테고리
                    
                    ### review
                    self.d_date.append(r_date) # 날짜 정보
                    self.score.append(score_dict[soup.select('div > div > div > p > span.info > span.label > span')[k*2]['class'][1][4:]])# 점수
                    self.like_c.append(" ") # 좋아요개수 
                    self.tags.append(" ") # 태그
                    self.text.append(soup.select('section.section-list-item > ul.review-list-wrap > li > div > p')[k].text)    # 리뷰 텍스트
                
                    
                    ### user
                    self.age.append(soup.select('section.section-list-item > ul.review-list-wrap > li > div > div > div > p > span.info > span.txt')[k].text[:3]) # 나이
                    self.skin_type.append(re.sub("·","",soup.select('section.section-list-item > ul.review-list-wrap > li > div > div > div > p > span.info > span.txt')[k].text[4:]).strip()) # 피부타입
                    self.concern_list.append(" ") # 피부고민
                    self.repurchased.append(" ") # 재구매
                    
                    # 유저 이름
                    # self.user_name.append(soup.select('section.section-list-item > ul.review-list-wrap > li > div > div > div > p > span.name')[k].text)
                     
    # 리스트들의 길이를 체크
    def chk_len(self):
        print(len(self.pid))
        print(len(self.pname))
        print(len(self.brandname))
        print(len(self.age))
        print(len(self.tags))
        print(len(self.repurchased))
        print(len(self.like_c))
        print(len(self.category))
        print(len(self.skin_type))
        print(len(self.score))
        print(len(self.d_date))
        print(len(self.text))
        print(len(self.concern_list))
        
    def printclass(self):
        print(self.headers)
    
    # 데이터 프레임을 만드는 함수
    def get_df(self):
        data = self.pd.DataFrame(
            {'brandname': self.brandname,
            'pid': self.pid,
             'pname' : self.pname,
             'age':self.age,
             'tags':self.tags,
             'repurchased':self.repurchased,
             'like_c':self.like_c,
             'category':self.category,
             'concern_list':self.concern_list,
             'skin_type':self.skin_type,
             'score':self.score,
             'date':self.d_date,
             'text':self.text
            })
        self.result_df=DataFrame(data)
        self.result_df=DataFrame(data, columns=['category','brandname',"pid",'pname','age','tags','repurchased','like_c','concern_list','skin_type','score','date','text'])
        return self.result_df
        #print(result_df)

# %%
# memebox.result_df=memebox.result_df.loc[:,('category','brandname','pid','pname','score','text','date','like_c','skin_type','requrchased')]
# powderroom.result_df=powderroom.result_df.loc[:,('brandname',"pid",'pname','age','tags','repurchased','like_c','concern_list','skin_type','score','date','text')]

# %%
# 리뷰간 중복을 제거하는 함수, 중복이 제거된 데이터 프레임만 qwe에 저장
# 크롤링한 리뷰들을 병합 + 글로우픽 추가 필요

# merged_df=pd.concat([memebox.result_df,powderroom.result_df])

# raw_tier1=db.raw_review_tier1
# ex_raw_tier1 = pd.Series([doc for doc in raw_tier1.find()])
# tt_date=datetime.today().strftime('%Y-%m-%d') # 오늘 
# yesterday = date.today() - timedelta(1)
# yy_date=yesterday.strftime('%Y-%m-%d') # 어제
# raw1_brandname=[]
# raw1_pname=[]
# raw1_date=[]
# raw1_text=[]

# for i in range(len(ex_raw_tier1)):
#     date_A=re.sub("[^0-9]","-",date_transfer(ex_raw_tier1[i]['review']['date']))
#     if date_A==tt_date or date_A==yy_date:
#         raw1_brandname.append(ex_raw_tier1[i]['product']['brandname'])
#         raw1_pname.append(ex_raw_tier1[i]['product']['pname'])
#         raw1_date.append(date_A)
#         raw1_text.append(ex_raw_tier1[i]['review']['text'])

# data = pd.DataFrame({'brandname':raw1_brandname,'pname' : raw1_pname,'date':raw1_date,'text':raw1_text})
# saved_df=DataFrame(data)
# saved_df=DataFrame(data, columns=['brandname','pname','date','text'])
# qwe=pd.concat([merged_df,saved_df])
# qwe=qwe.drop_duplicates(['date','text','pname'])

# %%
# #### customized_twitter tokenizer
# # 브랜드 이름 명사로 저장


# brand_set = np.array([re.sub('[^가-힣]','',x) for x in product_DB.brandname.unique()])
# brand_set = pd.Series([x for x in brand_set if x != ''])

# # 특수 이름 추가
# brand_set = brand_set.append(pd.Series(['비씨데이션','파데','다크닝','지속력','밀착력','피부톤','커버력','쿨톤','웜톤','결보정','코끼임']),ignore_index=True)

# # 트위터 tokenizer loading 및 업로드
# twitter = Twitter()
# twitter.add_dictionary(brand_set,'Noun')

# # 원래 tokenizer 업로드
# ori_twitter = original_Twitter()
# #### emoji2text
# preprocessed_text = emoji2text(review_DB.text)
# #### upper & 제품 매핑
# preprocessed_text = pd.Series(preprocessed_text).apply(lambda x:x.upper())
# #### twitter tokenizing 명사는 customized 나머지는 original
# bow = preprocessed_text.apply(lambda x:','.join([ori_twitter.pos(token,stem=True,norm=True)[0][0] if pos in ['Adjective','Verb'] else token for token, pos in twitter.pos(x) if pos in ['Noun','Adjective','Verb','Alpha']]))

# %%
# #### add tokens to dataframe
# review_DB['text_token'] = bow

# %%
# review_DB['origin']=review_DB['pname']
# review_DB['origin_id']=review_DB['pid']
# review_DB=review_DB.drop(['brandname','pname','pid','category'],axis=1)
# temp=pd.merge(normalizer,review_DB,on='origin')
# temp
# temp=temp.drop('brandname',axis=1)
# result=pd.merge(product_DB,temp,on='pname')

# product = ["pid", "pname", "product_desc", "product_attribute", "product_volume", "product_price", "sales", "brandname",'category','origin_id']
# user_info = ['age','skin_type','concern_list','repurchased']
# review = ['date','score','text','text_token','tags']

# result = dataframe2json(result,product,user_info,review)

# for x in range(len(result)):
#     result[x]['product']['origin_id'] = int(result[x]['product']['origin_id']) 
#     result[x]['user']['repurchased'] = int(re.sub(' ','0',str(result[x]['user']['repurchased'])))
#     #result[x]['user']['repurchased']=int(result[x]['user']['repurchased'])
#     result[x]['review']['score'] = int(result[x]['review']['score'])

# %%
# #### mongoDB저장 코드
# client = MongoClient("mongodb://pungdeong:pungdeong@13.125.143.101/pungdeongBOM")
# db = client.pungdeongBOM
# raw_review = db.raw_review_tier1 #요 collection에 쌓아라.
# raw_review.insert_many(result)

# %%
# 파이썬 파일을 실행할때 실행하고 싶은 명령 모두 아래에 입력
if __name__ == "__main__":
    
    # 사이트를 BOM_crawler 인스턴스로 할당
    memebox=bom_crawler()
    powderroom=bom_crawler()
    glowpick=bom_crawler()
    
    # id를 불러옴 
    meme_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/memebox/meme_id.csv')
    gl_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/glowpick/gl_id.csv')
    pod_id = pd.read_csv('C:/Users/Ilhoon/Anaconda_project/ebiz_CAPSTONE/crawling/powderroom/pod_id.csv')
    
    # 사이트별 리뷰 크롤링
    powderroom.powder_review_crawl()
    memebox.meme_review_crawl()
    glowpick.glowpick_review_crawl()
    # 크롤링한 데이터 프레임 저장
    powderroom.get_df()
    memebox.get_df()
    glowpick.get_df()
    
    
    # crawled data set / 중복을제거
    # 6/6 새로 추가된 데이터
    #************************ 이후 부터는 중복을 제거한 리뷰만 넣기 위해 review_DB=qwe로 변경
    # 리뷰간 중복을 제거하는 함수, 중복이 제거된 데이터 프레임만 qwe에 저장
    # 크롤링한 리뷰들을 병합 + 글로우픽 추가 필요

    merged_df=pd.concat([memebox.result_df,powderroom.result_df])
    raw_tier1=db.raw_review_tier1
    ex_raw_tier1 = pd.Series([doc for doc in raw_tier1.find()])
    tt_date=datetime.today().strftime('%Y-%m-%d') # 오늘 
    yesterday = date.today() - timedelta(1)
    yy_date=yesterday.strftime('%Y-%m-%d') # 어제
    raw1_brandname=[]
    raw1_pname=[]
    raw1_date=[]
    raw1_text=[]

    for i in range(len(ex_raw_tier1)):
        date_A=re.sub("[^0-9]","-",date_transfer(ex_raw_tier1[i]['review']['date']))
        if date_A==tt_date or date_A==yy_date:
            raw1_brandname.append(ex_raw_tier1[i]['product']['brandname'])
            raw1_pname.append(ex_raw_tier1[i]['product']['pname'])
            raw1_date.append(date_A)
            raw1_text.append(ex_raw_tier1[i]['review']['text'])

    data = pd.DataFrame({'brandname':raw1_brandname,'pname' : raw1_pname,'date':raw1_date,'text':raw1_text})
    saved_df=DataFrame(data)
    saved_df=DataFrame(data, columns=['brandname','pname','date','text'])
    qwe=pd.concat([merged_df,saved_df])
    qwe=qwe.drop_duplicates(['date','text','pname'])

    review_DB=qwe
    
    #### customized_twitter tokenizer
    # 브랜드 이름 명사로 저장


    brand_set = np.array([re.sub('[^가-힣]','',x) for x in product_DB.brandname.unique()])
    brand_set = pd.Series([x for x in brand_set if x != ''])

    # 특수 이름 추가
    brand_set = brand_set.append(pd.Series(['비씨데이션','파데','다크닝','지속력','밀착력','피부톤','커버력','쿨톤','웜톤','결보정','코끼임']),ignore_index=True)

    # 트위터 tokenizer loading 및 업로드
    twitter = Twitter()
    twitter.add_dictionary(brand_set,'Noun')

    # 원래 tokenizer 업로드
    ori_twitter = original_Twitter()
    #### emoji2text
    preprocessed_text = emoji2text(review_DB.text)
    #### upper & 제품 매핑
    preprocessed_text = pd.Series(preprocessed_text).apply(lambda x:x.upper())
    
    bow = preprocessed_text.apply(lambda x:'◈'.join([token+ '╹' + pos if pos in ['Noun'] else ori_twitter.pos(token,stem=True,norm=True)[0][0]+'╹'+ori_twitter.pos(token,stem=True,norm=True)[0][1] for token, pos in twitter.pos(x)]))
    ### token normalizing 
    p_normal = {'BB╹Alpha':'비비크림╹Noun', 'CC╹Alpha':'씨씨크림╹Noun','비비╹Noun':'비비크림╹Noun','씨씨╹Noun':'씨씨크림╹Noun'
                ,'파데╹Noun':'파운데이션╹Noun','쟂빛╹Noun':'잿빛╹Noun','비씨╹Noun':'비씨데이션╹Noun'}
    bow = bow.apply(lambda x: '◈'.join([p_normal[token] if token in p_normal.keys() else token for token in x.split('◈')]))
    #### add tokens to dataframe
    review_DB['text_token'] = bow
    
    
    
    review_DB['origin']=review_DB['pname']
    review_DB['origin_id']=review_DB['pid']
    review_DB=review_DB.drop(['brandname','pname','pid','category'],axis=1)
    temp=pd.merge(normalizer,review_DB,on='origin')
    temp
    temp=temp.drop('brandname',axis=1)
    result=pd.merge(product_DB,temp,on='pname')

    product = ["pid", "pname", "product_desc", "product_attribute", "product_volume", "product_price", "sales", "brandname",'category','origin_id']
    user_info = ['age','skin_type','concern_list','repurchased']
    review = ['date','score','text','text_token','tags']

    result = dataframe2json(result,product,user_info,review)

    for x in range(len(result)):
        result[x]['product']['origin_id'] = int(result[x]['product']['origin_id']) 
        result[x]['user']['repurchased'] = int(re.sub(' ','0',str(result[x]['user']['repurchased'])))
        #result[x]['user']['repurchased']=int(result[x]['user']['repurchased'])
        result[x]['review']['score'] = int(result[x]['review']['score'])
    
    print(result)
    #### mongoDB저장 코드
#     client = MongoClient("mongodb://pungdeong:pungdeong@13.125.143.101/pungdeongBOM")
#     db = client.pungdeongBOM
#     raw_review = db.raw_review_tier1 #요 collection에 쌓아라.
#     raw_review.insert_many(result)
# Out:
# https://www.powderroom.co.kr/api/products/32266/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32587/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31886/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32012/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32967/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27070/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7169482/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/3059892/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27130/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5008042/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32306/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5680961/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32280/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/56958/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2382756/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32908/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32162/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6944473/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5696160/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27092/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6810803/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6112581/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/71047/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/71761/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72755/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2380431/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5681182/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32910/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/55093/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/62599/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6328418/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8667938/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6259333/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6322957/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28941/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27184/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27192/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/71045/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4489813/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4492459/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5007786/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5231047/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5775239/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/50693/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6184394/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31880/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31881/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32277/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32672/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/3060285/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/58760/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/33008/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32645/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6175121/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6330385/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32855/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7169318/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32586/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32789/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/50657/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/1954206/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72293/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6112305/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31819/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6215558/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7636941/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21737059/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9637149/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2439599/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6347824/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6422757/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6792497/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7636773/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26284837/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7678331/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72746/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5174074/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5605972/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6287824/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/19677342/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9431819/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24227021/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24246426/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7924929/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5228076/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9225572/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/35858859/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22666929/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9947588/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/3065581/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27736353/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34562674/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34507761/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6112391/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72274/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2481453/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6242115/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6278373/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4618481/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22421903/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29253893/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29319815/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32299810/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29649/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/45994/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6328504/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/30632586/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26392691/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26684177/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/11342028/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22026746/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/16552526/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7569116/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31977/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6422901/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/12432031/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6244790/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24519076/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5620972/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2479775/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21432911/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24198535/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8538372/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25627792/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24529273/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2191868/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32711/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22532440/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9225389/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/36087503/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/36090286/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22407670/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6088951/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25635995/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32179523/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24856722/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/69712/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24526834/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34507670/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5155307/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7358971/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28087146/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22682948/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5710616/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9136529/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7674744/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/12432375/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26070596/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34508553/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6974547/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22403859/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9229949/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5794227/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/23505345/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7742462/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28094737/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/36411577/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21152370/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9787889/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/15255698/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/33998920/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4944400/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/23734329/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9988936/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6218251/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6131200/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24155079/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24019083/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5377774/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4870570/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29840573/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6192213/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8181383/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24095016/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/20701895/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29685/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5173918/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6306407/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4943382/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29615747/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6241555/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7694485/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22445650/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22301192/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21158029/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25663749/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25305968/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29697/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5171096/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8407440/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31526/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6178309/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29679/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5574063/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32517308/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/20641820/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7739004/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5171933/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8576261/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32321/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32569/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28862/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32952/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5850287/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6132301/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32014/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/600798/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5605823/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32900/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/1888322/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6066121/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6764/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6767/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5943497/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/33030/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/49543/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32537/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/70365/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6281344/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4617887/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5229694/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5621094/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27281/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32630/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32907/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/67067/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/71767/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72767/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4618332/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5345171/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5377206/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5681533/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5697338/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6048633/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6089026/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32423/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6978394/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7358921/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7440656/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6331679/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8654612/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8858315/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6278968/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29409391/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29422079/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29434409/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/33519266/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34376149/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/33139497/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/70350/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/15592881/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27731610/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5396955/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/23864180/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/69739/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34949013/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/15205169/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29663/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25706709/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7742564/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4618453/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5573973/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/10253917/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4895211/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5228890/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8115276/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2383372/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25658855/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72050/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/35254461/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5310680/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8559273/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22337003/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22407990/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/73939/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27992131/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9312518/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34453843/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4473303/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29158830/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25635835/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9476957/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27963589/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/72375/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22666898/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26995063/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/13756095/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26994861/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4641417/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27441430/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27424362/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27443423/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7636930/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/30072597/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/9149279/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26985645/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25635774/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27021769/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27019283/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21427918/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26684111/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4763826/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31418828/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27819797/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6156504/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4894845/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/21152478/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6178413/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24104610/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7440506/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7713962/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32948082/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8607653/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5036187/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6856767/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32231249/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28105037/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29832635/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7694458/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7692805/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7694343/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7603857/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/24104650/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31595081/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8932679/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/30086987/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/23584563/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/8814853/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/36420903/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34921927/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6705503/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/35717467/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/37420096/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25306020/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/34571658/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/12432066/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32707/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32702/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/27052/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32225/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32347/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/25191/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32793/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32081/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/19746345/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/51636/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32098/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/41582/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7429194/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/29721/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4766331/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/28953/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32342/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6493231/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32492/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/23494585/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32397/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32794/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32343/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32710/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31778/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/58699/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5794081/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32329/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32691/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6662009/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31781/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32642/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7276478/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/52816/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/3037561/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6193434/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/7119693/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/17109/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/30639329/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/31779/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32945/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32183/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5915919/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6182380/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5619908/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/16954419/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/69396/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2142216/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2439256/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2554600/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32841/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/2485625/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/19758953/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26930415/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/26017446/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/5913365/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/44976/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/4616010/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/22136755/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/32227/reviews?order=new
# ****************************************************
# https://www.powderroom.co.kr/api/products/6146287/reviews?order=new
# ****************************************************
# ...
# ****************************************************
# http://glowpick.com/product/20258
# ****************************************************
# http://glowpick.com/product/20255
# ****************************************************
# http://glowpick.com/product/20256
# ****************************************************
# http://glowpick.com/product/90693
# ****************************************************
# http://glowpick.com/product/73595
# ****************************************************
# http://glowpick.com/product/8190
# ****************************************************
# http://glowpick.com/product/8139
# ****************************************************
# http://glowpick.com/product/51685
# ****************************************************
# http://glowpick.com/product/8174
# ****************************************************
# http://glowpick.com/product/8138
# ****************************************************
# http://glowpick.com/product/8140
# ****************************************************
# http://glowpick.com/product/8064
# ****************************************************
# http://glowpick.com/product/11585
# ****************************************************
# http://glowpick.com/product/8184
# ****************************************************
# http://glowpick.com/product/59045
# ****************************************************
# http://glowpick.com/product/84900
# ****************************************************
# http://glowpick.com/product/98306
# ****************************************************
# http://glowpick.com/product/7965
# ****************************************************
# http://glowpick.com/product/8144
# ****************************************************
# http://glowpick.com/product/7963
# ****************************************************
# http://glowpick.com/product/7958
# ****************************************************
# http://glowpick.com/product/8131
# ****************************************************
# http://glowpick.com/product/87387
# ****************************************************
# http://glowpick.com/product/86353
# ****************************************************
# http://glowpick.com/product/75879
# ****************************************************
# http://glowpick.com/product/86988
# ****************************************************
# http://glowpick.com/product/75350
# ****************************************************
# http://glowpick.com/product/28221
# ****************************************************
# http://glowpick.com/product/69413
# ****************************************************
# http://glowpick.com/product/62081
# ****************************************************
# http://glowpick.com/product/12928
# ****************************************************
# http://glowpick.com/product/12923
# ****************************************************
# http://glowpick.com/product/12927
# ****************************************************
# http://glowpick.com/product/12861
# ****************************************************
# http://glowpick.com/product/11017
# ****************************************************
# http://glowpick.com/product/4261
# ****************************************************
# http://glowpick.com/product/4272
# ****************************************************
# http://glowpick.com/product/605
# ****************************************************
# http://glowpick.com/product/55677
# ****************************************************
# http://glowpick.com/product/3859
# ****************************************************
# http://glowpick.com/product/23797
# ****************************************************
# http://glowpick.com/product/56905
# ****************************************************
# http://glowpick.com/product/83280
# ****************************************************
# http://glowpick.com/product/18583
# ****************************************************
# http://glowpick.com/product/88658
# ****************************************************
# http://glowpick.com/product/88660
# ****************************************************
# http://glowpick.com/product/73371
# ****************************************************
# http://glowpick.com/product/38145
# ****************************************************
# http://glowpick.com/product/59279
# ****************************************************
# http://glowpick.com/product/57561
# ****************************************************
# http://glowpick.com/product/28346
# ****************************************************
# http://glowpick.com/product/102959
# ****************************************************
# http://glowpick.com/product/68313
# ****************************************************
# http://glowpick.com/product/73322
# ****************************************************
# http://glowpick.com/product/51357
# ****************************************************
# http://glowpick.com/product/3762
# ****************************************************
# http://glowpick.com/product/27323
# ****************************************************
# http://glowpick.com/product/77143
# ****************************************************
# http://glowpick.com/product/77102
# ****************************************************
# http://glowpick.com/product/90509
# ****************************************************
# http://glowpick.com/product/77116
# ****************************************************
# http://glowpick.com/product/27322
# ****************************************************
# http://glowpick.com/product/77175
# ****************************************************
# http://glowpick.com/product/77157
# ****************************************************
# http://glowpick.com/product/77184
# ****************************************************
# http://glowpick.com/product/1803
# ****************************************************
# http://glowpick.com/product/101218
# ****************************************************
# http://glowpick.com/product/4414
# ****************************************************
# http://glowpick.com/product/4415
# ****************************************************
# http://glowpick.com/product/4416
# ****************************************************
# http://glowpick.com/product/4153
# ****************************************************
# http://glowpick.com/product/50757
# ****************************************************
# http://glowpick.com/product/4419
# ****************************************************
# http://glowpick.com/product/607
# ****************************************************
# http://glowpick.com/product/41613
# ****************************************************
# http://glowpick.com/product/22100
# ****************************************************
# http://glowpick.com/product/4413
# ****************************************************
# http://glowpick.com/product/2114
# ****************************************************
# http://glowpick.com/product/4417
# ****************************************************
# http://glowpick.com/product/4156
# ****************************************************
# http://glowpick.com/product/4418
# ****************************************************
# http://glowpick.com/product/4421
# ****************************************************
# http://glowpick.com/product/26406
# ****************************************************
# http://glowpick.com/product/1784
# ****************************************************
# http://glowpick.com/product/47761
# ****************************************************
# http://glowpick.com/product/1799
# ****************************************************
# http://glowpick.com/product/13028
# ****************************************************
# http://glowpick.com/product/3048
# ****************************************************
# http://glowpick.com/product/13027
# ****************************************************
# http://glowpick.com/product/13025
# ****************************************************
# http://glowpick.com/product/13026
# ****************************************************
# http://glowpick.com/product/13029
# ****************************************************
# http://glowpick.com/product/13032
# ****************************************************
# http://glowpick.com/product/54909
# ****************************************************
# http://glowpick.com/product/13031
# ****************************************************
# http://glowpick.com/product/37014
# ****************************************************
# http://glowpick.com/product/27750
# ****************************************************
# http://glowpick.com/product/106167
# ****************************************************
# http://glowpick.com/product/99952
# ****************************************************
# http://glowpick.com/product/21133
# ****************************************************
# http://glowpick.com/product/106596
# ****************************************************
# http://glowpick.com/product/15981
# ****************************************************
# http://glowpick.com/product/15990
# ****************************************************
# http://glowpick.com/product/12823
# ****************************************************
# http://glowpick.com/product/12822
# ****************************************************
# http://glowpick.com/product/18650
# ****************************************************
# http://glowpick.com/product/40674
# ****************************************************
# http://glowpick.com/product/94275
# ****************************************************
# http://glowpick.com/product/32311
# ****************************************************
# http://glowpick.com/product/78919
# ****************************************************
# http://glowpick.com/product/11915
# ****************************************************
# http://glowpick.com/product/11752
# ****************************************************
# http://glowpick.com/product/82361
# ****************************************************
# http://glowpick.com/product/59571
# ****************************************************
# http://glowpick.com/product/38547
# ****************************************************
# http://glowpick.com/product/68477
# ****************************************************
# http://glowpick.com/product/51449
# ****************************************************
# http://glowpick.com/product/90596
# ****************************************************
# http://glowpick.com/product/51053
# ****************************************************
# http://glowpick.com/product/95818
# ****************************************************
# http://glowpick.com/product/39981
# ****************************************************
# http://glowpick.com/product/51057
# ****************************************************
# http://glowpick.com/product/26102
# ****************************************************
# http://glowpick.com/product/12466
# ****************************************************
# http://glowpick.com/product/101521
# ****************************************************
# http://glowpick.com/product/35310
# ****************************************************
# http://glowpick.com/product/88208
# ****************************************************
# http://glowpick.com/product/12462
# ****************************************************
# http://glowpick.com/product/93312
# ****************************************************
# http://glowpick.com/product/16727
# ****************************************************
# http://glowpick.com/product/26963
# ****************************************************
# http://glowpick.com/product/26965
# ****************************************************
# http://glowpick.com/product/12463
# ****************************************************
# http://glowpick.com/product/70813
# ****************************************************
# http://glowpick.com/product/12499
# ****************************************************
# http://glowpick.com/product/72916
# ****************************************************
# http://glowpick.com/product/25932
# ****************************************************
# http://glowpick.com/product/28442
# ****************************************************
# http://glowpick.com/product/77668
# ****************************************************
# http://glowpick.com/product/24461
# ****************************************************
# http://glowpick.com/product/7729
# ****************************************************
# http://glowpick.com/product/65637
# ****************************************************
# http://glowpick.com/product/76763
# ****************************************************
# http://glowpick.com/product/82355
# ****************************************************
# http://glowpick.com/product/8419
# ****************************************************
# http://glowpick.com/product/23783
# ****************************************************
# http://glowpick.com/product/82584
# ****************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-336723f91ee3> in <module>()
#      15     powderroom.powder_review_crawl()
#      16     memebox.meme_review_crawl()
# ---> 17     glowpick.glowpick_review_crawl()
#      18     # 크롤링한 데이터 프레임 저장
#      19     powderroom.get_df()
#
# <ipython-input-12-1a15bc6146d8> in glowpick_review_crawl(self)
#     149             time.sleep(1)
#     150             driver.get('http://glowpick.com/product/'+str(p_id)+'')
# --> 151             html = driver.page_source
#     152             soup = bs(html, 'lxml')
#     153             print('http://glowpick.com/product/'+str(p_id)+'')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     668             driver.page_source
#     669         """
# --> 670         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     671
#     672     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     308
#     309         params = self._wrap_value(params)
# --> 310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
#     312             self.error_handler.check_response(response)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     464         data = utils.dump_json(params)
#     465         url = '%s%s' % (self._url, path)
# --> 466         return self._request(command_info[0], url, body=data)
#     467
#     468     def _request(self, method, url, body=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     488             try:
#     489                 self._conn.request(method, parsed_url.path, body, headers)
# --> 490                 resp = self._conn.getresponse()
#     491             except (httplib.HTTPException, socket.error):
#     492                 self._conn.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
