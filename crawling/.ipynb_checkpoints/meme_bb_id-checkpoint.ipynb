# %%
import pandas as pd
from pandas import Series, DataFrame
import re
import numpy as np
from requests import get
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

# %%
phantomJS_path = 'C:/Users/Ilhoon/Desktop/dev_util/phantomjs-2.1.1-windows/bin/phantomjs'
driver = webdriver.PhantomJS(phantomJS_path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
# 페이지 스크롤 8번 내리면서 페이지에 보이는 모든 제품 다 가져오기
import time
driver.get('http://www.memebox.com/category/343/review')
i=0
while i<8:
    i = i+1
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
html = driver.page_source
soup = bs(html, 'lxml')

# %%
p_num = len(soup.select('#container > div.newDealContents > ul.dealList')) # 제품의 개수

# %%
def starnum(star): # 별의 텍스트를 뽑아내는 함수
    first=0
    second=0
    for i in range(len(star)):
        if star[i]=="\"":
            if first==0:
                first=i
            else: 
                second=i
    return star[first+1:second]

# %%
item_id=[]
item_name=[]
item_brand=[]
item_score=[]
num_of_reviews=[]

# %%
score_dic ={"":0,"one":1,"oneHalf":1.5,"two":2,"twoHalf":2.5,"three":3,"threeHalf":3.5,"four":4,"fourHalf":4.5,"five":5} 
# 텍스트에 대응되는 별점 딕셔너리로 저장

# %%
#리뷰가 하나도 없는 것을 어떻게 처리할 것인가.
for item in soup.select("#container > div.newDealContents > ul.dealList")[0].find_all('li'):
    if item.select("span > a > div.dealBottom > div.dealhead")[0].select('div') == "":
        print(item.get("data-product-name"))

# %%
for i in range(len(soup.select("#container > div.newDealContents > ul.dealList"))):
    for item in soup.select("#container > div.newDealContents > ul.dealList")[i].find_all('li'):
        if '4월' not in item.get("data-product-name"):
            try:
                num_of_reviews.append(item.select("span > a > div.dealBottom > div.dealhead > div.starBox > span.amount")[0].text[1:-1]) # 총 리뷰 개수
                    # 리뷰가 하나도 없는 제품에 대해서 에러. 
                item_id.append(item.get("data-product-id"))
                item_name.append(item.get("data-product-name"))
                item_brand.append(item.get("data-product-brand"))
                item_score.append(score_dic[starnum(str(item.select("span > a > div.dealBottom > div.dealhead > div.starBox > span > em")))]) # 별점 평균
            except:
                continue

# %%
data ={'item_id':item_id,
      'item_name':item_name,
      'item_brand':item_brand,
      'num_of_reviews':num_of_reviews,
      'item_score':item_score}
meme_bb_id=DataFrame(data)
meme_bb_id=DataFrame(data, columns=["item_id",'item_brand','item_name','num_of_reviews','item_score'])
meme_bb_id=meme_bb_id.loc[meme_bb_id.item_id!="524732",:]
meme_bb_id
# Out:
#    item_id item_brand                      item_name num_of_reviews  \
# 1   511587        프레티          [프레티] 퓨어 화이트 밀크 크림 2종            313
# 2    22685       바닐라코                [바닐라코] 커버10 컬렉션            253
# 3     5802       클레어스       [클레어스] 일루미네이팅 서플 블래미쉬 크림            231
# 4    21811       지베르니          [지베르니] 밀착 베이스 메이크업 7종            199
# 5    21337       바닐라코            [바닐라코] 잇 래디언트 CC 2종            180
# 6   520863         어퓨  [어퓨] 신상! 모이스트 크리미 컨실러&베이스 모음전            154
# 7    23241     에뛰드하우스           [에뛰드] 빅 커버 비비&컨실러                95
# 8    36038        위드미              [위드미] 스노우 화이트닝 크림             86
# 9   509912       토니모리          [토니모리] 루미너스 여신광채 비비크림             47
# 10   37698        라네즈                [라네즈] 비비쿠션 화이트닝             46
# 11   33671    네이크업페이스            [네이크업페이스] 워터킹 커버 쿠션             41
# 12  520129       아리따움                 [아리따움] 풀 커버 라인             41
# 13  521194        한스킨          [한스킨] 수퍼 쓰리 솔루션 비비크림              32
# 14   37687        라네즈              [라네즈] 비비쿠션 포어 컨트롤             28
# 15  511814        디케이                   [DK] 썬크림 1+1             27
# 16    9575     홀리카홀리카         [홀리카홀리카] 페이스2 체인지 롤러비비             26
# 17  525511         미바                     [미바] 비비크림              26
# 18   34581       유리피부        [유리피부] 셀룸 아마이드 비비 크림 2종             24
# 19  511420      스위스퓨어         [스위스퓨어] 톤업크림/커버크림/수딩크림             22
# 20  510584     에뛰드하우스          [에뛰드] 진주알 맑은 비비크림 10종             21
# 21  522067         어퓨                [어퓨] 윤광 비비크림 4종             20
# 22   12401        클리오          [클리오] 워터미 플리즈 비비 (AD)             19
# 23  521195        한스킨           [한스킨] 수퍼 라이트 터치 비비크림             18
# 24  523361        베쏘네           [베쏘네] 피치어밀크 메쉬 쿠션 3종             16
# 25  502533         미샤           [미샤] M 퍼펙트 커버 비비 크림              15
# 26  502656         헤라                [헤라] 에이지 리버스 쿠션             14
# 27    3762       슈에무라               [슈에무라] 워터 글로우 BB             13
# 28   36177       더블유랩                   [더블유랩] 감쪽 비비             12
# 29  522997         비쉬            [비쉬] 애라BB 미네랄 비비 2종             11
# 30   33523       보타닉팜          [보타닉팜] 도트 아트 컬렉션 CC쿠션             11
# 31   33674    네이크업페이스           [네이크업페이스] 커버킹 파우더 쿠션              9
# 32  511808        디케이                  [DK] 비비크림 1+1              8
# 33   36472        컬러랩                 [컬러랩] 우유 톤업 크림              8
# 34   36234       더블유랩                   [더블유랩] 철벽 비비              8
# 35   36200       더블유랩                  [더블유랩] 광채 부스터              7
# 36   36309      샬랑드파리        [샬랑드파리] 올킬 풀 HD 크림/마스크팩              7
# 37   32375     에뛰드하우스                 [에뛰드] 제로 피지 라인              7
# 38   36451       비알티씨      [BRTC]쟈스민 벨벳매직 프라이머/BB/CC              7
# 39   36229       더블유랩                  [더블유랩] 복숭아 크림              7
# 40  505589        라뮤즈                 [라뮤즈] 아쿠아 커버 밤              3
# 41   35379        클리오           [클리오] 킬커버 하이스트 웨어 팩트              3
# 42  514026        닥터지           [닥터지] 브라이트닝 밤/블레미쉬 밤              2
# 43   29143       아이오페                 [아이오페] CC크림 2종              2
# 44  518007         더샘            [더샘] 에코 소울 리얼 커버 비비              2
# 45  502544         미샤              [미샤] 금설 기윤 비비 케익               2
# 46  524691       페리페라           [페리페라] 잉크 뽀얀 스킨틴트 4종              2
# 47  513237         티암            [티암] 1초 화이트닝 커버 크림               2
# 48  510934      샬랑드파리              [샬랑드파리] 끄렘 드 에뚜알               2
# 49   29153         한율                   [한율] 비비크림 2종              2
# 50  524908         루나               [루나] 래스팅 비비팩트 2종              1
# 51  523379      닥터마인드              [닥터마인드] 커버팟 크림 2종              1
# 52  512435       듀이트리           [듀이트리] 더마미네랄 메이크업 4종              1
# 53  502538         미샤            [미샤] 링클 필업 비비크림 2종               1
# 54  522919        차앤박         [차앤박] 옴므 클렌징&비비&올인원 3종              1
# 55  511769         리르                  [리르] 스타일 롤링비비              1
#
#     item_score
# 1          4.5
# 2          4.5
# 3          4.5
# 4          4.5
# 5          5.0
# 6          4.0
# 7          4.5
# 8          4.5
# 9          4.5
# 10         4.5
# 11         4.5
# 12         4.5
# 13         4.5
# 14         4.5
# 15         4.5
# 16         4.5
# 17         4.5
# 18         4.5
# 19         4.5
# 20         4.5
# 21         4.0
# 22         4.0
# 23         4.5
# 24         5.0
# 25         4.5
# 26         5.0
# 27         4.5
# 28         4.0
# 29         4.5
# 30         4.0
# 31         4.0
# 32         5.0
# 33         4.5
# 34         4.5
# 35         5.0
# 36         4.5
# 37         4.5
# 38         4.5
# 39         4.0
# 40         4.5
# 41         4.0
# 42         5.0
# 43         5.0
# 44         4.5
# 45         4.5
# 46         4.5
# 47         4.5
# 48         4.5
# 49         4.0
# 50         5.0
# 51         5.0
# 52         5.0
# 53         5.0
# 54         4.5
# 55         4.0

# %%
meme_bb_id.to_csv('meme_bb_id.csv',sep=",", encoding="UTF-8")
