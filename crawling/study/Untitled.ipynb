# %%
from requests import get
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
url='https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=156098&target=after'
html=get(url).text
soup=bs(html,'html.parser')

# %%
print(soup.select('td.title')[3].text)
# Out:
# 미세스 하이드
# 영화가 정말 괴짜네.. ㅋ 제목이 평범하게 느껴져
#
#
#
#
#
#
# 				신고

# %%
for i in range(1,10):
    url='https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=136315&target=after&page='+str(i)+''
    html=get(url).text
    soup=bs(html,'html.parser')
    for j in range(10):
        print(soup.select('td.title')[j].text)
# Out:
# 어벤져스: 인피니티 워
# 충격적인 결말.ㅎㄷㄷ
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 간만에 맛본 할리우드의 정수
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 다음이 기대되네요 좀 충격이얏지만 ...
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 크... 10년의결실
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 톰홀랜드잘생겼다!!
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 마블 영화를 시리즈별로 다 챙겨본게 아니여서 전개는 잘 이해가 안갔지만 잘만들었네요
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 재밋게 잘봤습니다!!!
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 번역가 짤라주세요 제발재발
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 토르는 신이니까 마지막에 인피니티 스톤 다모아서 손가락 딱 할때 안주고 나머지는 거의 다 죽죠  이번엔 액션씬이 많아서 좋았고 다음편 기대합니다.
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 진짜 사랑해요 마블ㅠㅠㅠ
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 재미있었어요강추강추
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 영상 자체는 정말 다음편이 기대되는 좋은 영상이었지만 번역의 힘이 정말  중요하다는 것을 깨달았네요
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 번역어찌좀해라...
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 믿고보는 마블!! 번역은 실망 ㅠㅠ
#
#
#
#
#
#
# 				신고
#
#
# 어벤져스: 인피니티 워
# 재밌어요 마지막에 영상도 놓치지마세요
#
#
#
#
#
#
# 				신고
#
#
# ...

# %%
a='  ewrwer        qwer         '

# %%
print(a)
# Out:
#   ewrwer        qwer

# %%
print(a.strip())
# Out:
# ewrwer        qwer

# %%
import re

# %%
print(re.sub(" ","",a))
# Out:
# ewrwerqwer
