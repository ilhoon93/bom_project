# %%
import pandas as pd
from pandas import Series, DataFrame
import re
import numpy as np
from requests import get
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import pyautogui # 파이썬 매크로 모듈

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

# %%
brand_data=pd.read_csv('brand_data.csv')

# %%
chrome_path = 'C:/Users/Ilhoon/Desktop/dev_util/chromedriver_win32/chromedriver'
driver = webdriver.Chrome(chrome_path)

# %%
# 브랜드 id로 각각 url 접근
brand_name=[] # 브랜드명
product_name=[] # 브랜드이름
product_id=[] # 제품 ID
product_volume=[] # 제품 용량
product_price=[] # 제품 가격
product_score=[] # 제품 평점
product_score_joiner=[] # 제품 평점 참여자 수

# %%
t_brand_name=[] # 브랜드명
t_product_name=[] # 브랜드이름
t_product_id=[] # 제품 ID
t_product_volume=[] # 제품 용량
t_product_price=[] # 제품 가격
t_product_score=[] # 제품 평점
t_product_score_joiner=[] # 제품 평점 참여자 수

# %%
pyautogui.moveTo(1910, 1008.5)

# %%
# 제품 id 기준 내림차순 정렬 모든 제품 정보 있는 페이지
driver.get('http://glowpick.com/search/result?')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a3354fd70e1> in <module>()
#       1 # 제품 id 기준 내림차순 정렬 모든 제품 정보 있는 페이지
# ----> 2 driver.get('http://glowpick.com/search/result?')
#
# NameError: name 'driver' is not defined

# %%
for k in range(len(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info'))): # 브랜드별 아이템정보 담고 있는 개체
    t_brand_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h5.brand')[0].text) # 브랜드 명
    t_product_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h6.name')[0].text) # 제품 명
    t_product_id.append(re.sub("[^0-9]","",soup.select('div.comp-card-prod')[k].get('data-url'))) # 제품 id 
    t_product_volume.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.volume')[0].text) # 용량
    t_product_price.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.price')[0].text) # 가격
    t_product_score.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.score')[0].text) # 평점
    t_product_score_joiner.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.joiner')[0].text[1:-1]) # 평점 참여자 수

# %%
for k in range(len(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info'))): # 브랜드별 아이템정보 담고 있는 개체
    brand_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h5.brand')[0].text) # 브랜드 명
    product_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h6.name')[0].text) # 제품 명
    product_id.append(re.sub("[^0-9]","",soup.select('div.comp-card-prod')[k].get('data-url'))) # 제품 id 
    product_volume.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.volume')[0].text) # 용량
    product_price.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.price')[0].text) # 가격
    product_score.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.score')[0].text) # 평점
    product_score_joiner.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.joiner')[0].text[1:-1]) # 평점 참여자 수

# %%
driver.get('http://glowpick.com/brand/ranking?id=86')

# %%
#  아리따움, 디올, 에뛰드하우스, /에스티 로더 
driver.get('http://glowpick.com/brand/ranking?id=163')
time.sleep(1)
for i in range(230):
    screenWidth, screenHeight = pyautogui.size()
    currentMouseX, currentMouseY = pyautogui.position()
    pyautogui.moveTo(1910, 1008.5)
    pyautogui.click()

html = driver.page_source
soup = bs(html, 'lxml')

for k in range(len(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info'))): # 브랜드별 아이템정보 담고 있는 개체
    brand_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h5.brand')[0].text) # 브랜드 명
    product_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h6.name')[0].text) # 제품 명
    product_id.append(re.sub("[^0-9]","",soup.select('div.comp-card-prod')[k].get('data-url'))) # 제품 id 
    product_volume.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.volume')[0].text) # 용량
    product_price.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.price')[0].text) # 가격
    product_score.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.score')[0].text) # 평점
    product_score_joiner.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.joiner')[0].text[1:-1]) # 평점 참여자 수

# %%
# run crawling
j=1
for ID in brand_data['brand_id'][2499:2500]: # 모든 브랜드 ID별로 url 접근, 1차로 1000개 브랜드 제품 크롤링
    # 5/3 10:30 306(니베아포맨까지)
    driver.get('http://glowpick.com/brand/ranking?id='+str(ID)+'')
    
    for i in range(30):
        screenWidth, screenHeight = pyautogui.size()
        currentMouseX, currentMouseY = pyautogui.position()
        pyautogui.moveTo(1910, 1008.5)
        pyautogui.click()
        
    html = driver.page_source
    soup = bs(html, 'lxml')
    print(j) # 브랜드 넘어갈 때 마다 1씩 더해가면서 출력(진행상황을 보기 위해 )
    j+=1
    
    for k in range(len(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info'))): # 브랜드별 아이템정보 담고 있는 개체
        brand_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h5.brand')[0].text) # 브랜드 명
        product_name.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > h6.name')[0].text) # 제품 명
        product_id.append(re.sub("[^0-9]","",soup.select('div.comp-card-prod')[k].get('data-url'))) # 제품 id 
        product_volume.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.volume')[0].text) # 용량
        product_price.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-prod > p > span.price')[0].text) # 가격
        product_score.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.score')[0].text) # 평점
        product_score_joiner.append(soup.select('div.comp-card-prod > div.prod-wrap > div.side-info')[k].select('div.side-score > div > span.joiner')[0].text[1:-1]) # 평점 참여자 수
# Out:
# 1

# %%
data={'brand_name':brand_name,
      'product_id':product_id,
     'product_name':product_name,
     'product_volume':product_volume,
     'product_price':product_price,
     'product_score':product_score,
     'product_score_joiner':product_score_joiner}
product_data=DataFrame(data)
product_data=DataFrame(data, columns=['brand_name','product_id','product_name','product_volume','product_price','product_score','product_score_joiner'])
product_data
# Out:
#      brand_name product_id                                       product_name  \
# 0          아리따움      34262                                          아이돌래쉬 내추럴
# 1          아리따움      79094                                     아이돌 브로우 파우더 케익
# 2          아리따움      80140                                          아이스 카밍 쿨러
# 3          아리따움      16899                                    진저슈가 오버나이트 립마스크
# 4          아리따움      14146                                       엔젤링 케어 헤어 앰플
# 5          아리따움      72293                                        매직 컨투어링 파우더
# 6          아리따움      89811                                     NEW 모노아이즈 - 매트
# 7          아리따움      89728                                     NEW 모노아이즈 - 쉬머
# 8          아리따움      88929                                     NEW 슈가볼 벨벳 블러셔
# 9          아리따움      65345                                      두피마사지용 쿠션 브러쉬
# 10         아리따움      21230                                           샤인픽스 아이즈
# 11         아리따움      78557                                       아이돌 리얼 래쉬 픽서
# 12         아리따움      25775                                       더 프로페셔널 아이래쉬
# 13         아리따움      92934                                         아이돌래쉬 프리미엄
# 14         아리따움      77327                          프레시파워 에센스 마스크팩 알로에 (쿨링진정)
# 15         아리따움      62313                                   매트 포뮬라 아이 브로우 펜슬
# 16         아리따움      33748                                      알로에 노워시 클렌징워터
# 17         아리따움      83123                              프레시 파워 에센스 파우치 팩 강력보습
# 18         아리따움      89725                                    NEW 모노아이즈 - 글리터
# 19         아리따움      77339                            프레시파워 에센스 마스크팩 쑥 (수딩진정)
# 20         아리따움      55261                                          모디 쥬얼 스티커
# 21         아리따움      77326                          프레시파워 에센스 마스크팩 티트리 (산뜻진정)
# 22         아리따움      20253                                        진저슈가 에센셜 립밤
# 23         아리따움      88928                                     NEW 슈가볼 쿠션 블러셔
# 24         아리따움      14167                                      모디 익스트림 네일리무버
# 25         아리따움      94804                                      모디 젤 네일 디자인 팁
# 26         아리따움      26421                                         슈가볼 벨벳 블러셔
# 27         아리따움      21261                                             버블 거품망
# 28         아리따움     103497                                       모노 아이즈 틴트 스틱
# 29         아리따움      87080                                      퍼퓸테일러 핸드크림 피치
# ...         ...        ...                                                ...
# 2135     에스티 로더      95849  크레센트 화이트 풀 사이클 브라이트닝 BB 크림 앤 브라이트닝 밤 SPF50+ PA...
# 2136     에스티 로더      95882                           크레센트 화이트 풀 사이클 브라이트닝 클렌저
# 2137     에스티 로더      95888                                   클리어 디퍼런스 아쿠아 젤크림
# 2138     에스티 로더      86931                                         탠제르 바닐 EDP
# 2139     에스티 로더      86932                                         탠제르 바닐 롤러볼
# 2140     에스티 로더      86933                                        탠제르 바닐 바디크림
# 2141     에스티 로더      62069                                       텐더 블러쉬 쉬어 스틱
# 2142     에스티 로더       6420                              퍼펙셔니스트 [CP+R]  라인 스무더
# 2143     에스티 로더     104864                        퍼펙셔니스트 프로 래피드 펌 + 리프트 트리트먼트
# 2144     에스티 로더       6441                                         퍼펙팅 루스 파우더
# 2145     에스티 로더      95915                                       퍼펙팅 메이크업 미스트
# 2146     에스티 로더       6466                                 퓨어 칼라 네일 락카 베이스 코트
# 2147     에스티 로더       6465                                   퓨어 칼라 네일 락카 탑 코트
# 2148     에스티 로더      11334                              퓨어 칼라 네일 락카 헤비 페탈 컬렉션
# 2149     에스티 로더       6447                             퓨어 칼라 더 메탈릭 비비드 샤인 립스틱
# 2150     에스티 로더      73710                                      퓨어 칼라 러쉬 립 샤인
# 2151     에스티 로더       6445                                          퓨어 칼라 블러시
# 2152     에스티 로더       6450                                    퓨어 칼라 쉬어 매트 립스틱
# 2153     에스티 로더      16860                                퓨어 칼라 엔비 스컬프팅 아이섀도우
# 2154     에스티 로더      34379                                  퓨어 칼라 올 오버 일루미네이터
# 2155     에스티 로더        493                                 퓨어 칼라 젤리 파우더 아이섀도우
# 2156     에스티 로더       6444                                        퓨어 칼라 치크 러쉬
# 2157     에스티 로더       6473                    프로 라인 엑스퍼트 메이크업 브러시 블렌딩 섀도우 브러시
# 2158     에스티 로더       6471                  프로 라인 엑스퍼트 메이크업 브러시 아이라이너/브로우 브러시
# 2159     에스티 로더       6469                        프로 라인 엑스퍼트 메이크업 브러시 파우더 브러시
# 2160     에스티 로더       6467                  프로 라인 엑스퍼트 메이크업 브러시 파우더 파운데이션 브러시
# 2161     에스티 로더       6503                                      플레져 배쓰 앤 샤워 젤
# 2162     에스티 로더      27314                                         플레져 블룸 EDP
# 2163     에스티 로더       6509                                플레져 포 맨 포 맨 코롱 스프레이
# 2164     에스티 로더       6424                               하이드라 컴플리트 모이스춰 젤 마스크
#
#      product_volume product_price product_score product_score_joiner
# 0               1ea        6,000원          4.38                1,108
# 1                4g        6,000원          4.37                1,241
# 2                1p       10,000원          4.35                  147
# 3               25g        9,000원          4.28                1,797
# 4               8ml        2,000원          4.28                  241
# 5                7g        8,000원          4.21                3,662
# 6              1.2g        5,000원          4.18                1,247
# 7              1.2g        5,000원          4.22                  740
# 8                8g        8,000원          4.20                  853
# 9               1ea        4,500원          4.23                   92
# 10               3g        8,000원          4.11                2,603
# 11              8ml        6,000원          4.18                1,074
# 12               2p        3,000원          4.17                  230
# 13              1ea        6,000원          4.38                   55
# 14             20ml        1,000원          4.14                  140
# 15               3g        4,000원          4.08                4,278
# 16            300ml        6,000원          4.07                  780
# 17             10ml        1,000원          4.13                  533
# 18             1.2g        5,000원          4.08                  628
# 19             20ml        1,000원          4.01                  890
# 20               1p        4,500원          4.27                   55
# 21             20ml        1,000원          4.02                  467
# 22             15ml        6,000원          4.03                  596
# 23               6g        8,000원          4.01                  739
# 24            150ml        4,500원          4.01                  208
# 25              1ea        9,700원          4.15                   62
# 26               8g        8,000원          3.91                  771
# 27              1ea        2,000원          3.95                  147
# 28             0.5g        7,000원          4.54                   41
# 29             30ml        3,500원          4.27                   52
# ...             ...           ...           ...                  ...
# 2135           30ml       65,000원          0.00                    0
# 2136          125ml       47,000원          0.00                    0
# 2137           50ml       93,000원          0.00                    0
# 2138          100ml      200,000원          0.00                    0
# 2139            8ml       45,000원          0.00                    0
# 2140          150ml       68,000원          0.00                    0
# 2141           8.7g       38,000원          0.00                    0
# 2142           15ml       90,000원          0.00                    0
# 2143           50ml      160,000원          0.00                    0
# 2144            10g       58,000원          0.00                    0
# 2145       116ml          40,000원          0.00                    0
# 2146            9ml       22,000원          0.00                    0
# 2147            9ml       20,000원          0.00                    0
# 2148            9ml       26,000원          0.00                    0
# 2149           3.8g       39,000원          0.00                    0
# 2150             2g       38,000원          2.00                    1
# 2151             7g       49,000원          4.59                   44
# 2152             2g       36,000원          0.00                    0
# 2153             7g       70,000원          0.00                    0
# 2154             7g       50,000원          0.00                    0
# 2155           0.9g       31,000원          0.00                    0
# 2156             8g       39,000원          4.00                    2
# 2157              0       40,000원          0.00                    0
# 2158              0       30,000원          0.00                    0
# 2159              0       65,000원          0.00                    0
# 2160              0       60,000원          0.00                    0
# 2161          150ml       45,000원          0.00                    0
# 2162          500ml       85,000원          0.00                    0
# 2163          100ml       90,000원          0.00                    0
# 2164           75ml       45,000원          0.00                    0
#
# [2165 rows x 7 columns]

# %%
product_data.to_csv('pd_last.csv',sep=",",encoding="UTF-8")
